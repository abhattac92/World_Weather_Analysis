# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests
import time
import gmaps
from config import weather_api_key
from config import g_key

# %%
# Create a set of 1500 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 595

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3a0ba330c1a35fe48f61add10f66ffea

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        continue
    try:
        city_rainfall = city_weather["rain"]["1h"]
    except KeyError:
        city_rainfall = 0.0
        pass
    try:
        city_snowfall = city_weather["snow"]["1h"]
    except KeyError:
        city_snowfall = 0.0
        pass
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Rain (inches)": city_rainfall,
                          "Snow (inches)": city_snowfall})
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bang len
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | nanortalik
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | ladybrand
# Processing Record 7 of Set 1 | cherskiy
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | amazar
# Processing Record 10 of Set 1 | mareeba
# Processing Record 11 of Set 1 | mount isa
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | mabaruma
# Processing Record 15 of Set 1 | chokurdakh
# Processing Record 16 of Set 1 | dingle
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | cidreira
# Processing Record 21 of Set 1 | saint-joseph
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | baiyin
# Processing Record 24 of Set 1 | buluang
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | muros
# Processing Record 30 of Set 1 | berlevag
# Processing Record 31 of Set 1 | lompoc
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | edson
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 1 | aklavik
# Processing Record 38 of Set 1 | novyy urengoy
# Processing Record 39 of Set 1 | oktyabrskoye
# Processing Record 40 of Set 1 | tuktoyaktuk
# Processing Record 41 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 1 | severo-kurilsk
# Processing Record 43 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | jumla
# Processing Record 46 of Set 1 | wampusirpi
# City not found. Skipping...
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | lebyazhye
# Processing Record 2 of Set 2 | new norfolk
# Processing Record 3 of Set 2 | vao
# Processing Record 4 of Set 2 | palmer
# Processing Record 5 of Set 2 | ahipara
# Processing Record 6 of Set 2 | luoyang
# Processing Record 7 of Set 2 | rena
# Processing Record 8 of Set 2 | umm kaddadah
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | verkhovazhye
# Processing Record 11 of Set 2 | faya
# Processing Record 12 of Set 2 | mandan
# Processing Record 13 of Set 2 | kitgum
# Processing Record 14 of Set 2 | mossoro
# Processing Record 15 of Set 2 | wenatchee
# Processing Record 16 of Set 2 | hamilton
# Processing Record 17 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 18 of Set 2 | guerrero negro
# Processing Record 19 of Set 2 | ancud
# Processing Record 20 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 2 | arriaga
# Processing Record 23 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 2 | imbituba
# Processing Record 25 of Set 2 | kodiak
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | palana
# Processing Record 28 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 29 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 2 | waingapu
# Processing Record 31 of Set 2 | urumqi
# Processing Record 32 of Set 2 | sibenik
# Processing Record 33 of Set 2 | butaritari
# Processing Record 34 of Set 2 | saskylakh
# Processing Record 35 of Set 2 | terrace
# Processing Record 36 of Set 2 | vaasa
# Processing Record 37 of Set 2 | san lawrenz
# Processing Record 38 of Set 2 | north bend
# Processing Record 39 of Set 2 | los llanos de aridane
# Processing Record 40 of Set 2 | hithadhoo
# Processing Record 41 of Set 2 | zhigansk
# Processing Record 42 of Set 2 | bosaso
# Processing Record 43 of Set 2 | bethel
# Processing Record 44 of Set 2 | constitucion
# Processing Record 45 of Set 2 | bang yai
# Processing Record 46 of Set 2 | labuhan
# Processing Record 47 of Set 2 | jhunjhunun
# Processing Record 48 of Set 2 | sao filipe
# Processing Record 49 of Set 2 | hilo
# Processing Record 50 of Set 2 | tiksi
# Processing Record 1 of Set 3 | chapadinha
# Processing Record 2 of Set 3 | waspan
# Processing Record 3 of Set 3 | santa maria
# Processing Record 4 of Set 3 | mataura
# Processing Record 5 of Set 3 | khatanga
# Processing Record 6 of Set 3 | padang
# Processing Record 7 of Set 3 | tessalit
# Processing Record 8 of Set 3 | pineville
# Processing Record 9 of Set 3 | arraial do cabo
# Processing Record 10 of Set 3 | oktyabrskiy
# Processing Record 11 of Set 3 | menongue
# Processing Record 12 of Set 3 | klenovyy
# Processing Record 13 of Set 3 | hasaki
# Processing Record 14 of Set 3 | naze
# Processing Record 15 of Set 3 | puerto cabezas
# Processing Record 16 of Set 3 | maragogi
# Processing Record 17 of Set 3 | mao
# Processing Record 18 of Set 3 | el penon
# Processing Record 19 of Set 3 | mitsamiouli
# Processing Record 20 of Set 3 | evensk
# Processing Record 21 of Set 3 | east london
# Processing Record 22 of Set 3 | sinnamary
# Processing Record 23 of Set 3 | cilegon
# Processing Record 24 of Set 3 | bongandanga
# Processing Record 25 of Set 3 | katete
# Processing Record 26 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 3 | tasiilaq
# Processing Record 28 of Set 3 | shahr-e babak
# Processing Record 29 of Set 3 | sao gabriel da cachoeira
# Processing Record 30 of Set 3 | great yarmouth
# Processing Record 31 of Set 3 | belmonte
# Processing Record 32 of Set 3 | tongzi
# Processing Record 33 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 3 | eugene
# Processing Record 35 of Set 3 | thompson
# Processing Record 36 of Set 3 | ponta do sol
# Processing Record 37 of Set 3 | yellandu
# Processing Record 38 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 3 | szihalom
# Processing Record 40 of Set 3 | myitkyina
# Processing Record 41 of Set 3 | yar-sale
# Processing Record 42 of Set 3 | nome
# Processing Record 43 of Set 3 | ponta delgada
# Processing Record 44 of Set 3 | balimo
# City not found. Skipping...
# Processing Record 45 of Set 3 | port hedland
# Processing Record 46 of Set 3 | kavieng
# Processing Record 47 of Set 3 | podsineye
# Processing Record 48 of Set 3 | provideniya
# Processing Record 49 of Set 3 | limanowa
# Processing Record 50 of Set 3 | kaeo
# Processing Record 1 of Set 4 | esperance
# Processing Record 2 of Set 4 | kutum
# Processing Record 3 of Set 4 | vardo
# Processing Record 4 of Set 4 | tommot
# Processing Record 5 of Set 4 | ostrovnoy
# Processing Record 6 of Set 4 | conakry
# Processing Record 7 of Set 4 | norman wells
# Processing Record 8 of Set 4 | airai
# Processing Record 9 of Set 4 | gubskaya
# Processing Record 10 of Set 4 | oranjemund
# Processing Record 11 of Set 4 | klaksvik
# Processing Record 12 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 4 | salina cruz
# Processing Record 14 of Set 4 | yulara
# Processing Record 15 of Set 4 | talara
# Processing Record 16 of Set 4 | hami
# Processing Record 17 of Set 4 | lorengau
# Processing Record 18 of Set 4 | husavik
# Processing Record 19 of Set 4 | balykshi
# City not found. Skipping...
# Processing Record 20 of Set 4 | anadyr
# Processing Record 21 of Set 4 | bredasdorp
# Processing Record 22 of Set 4 | bambous virieux
# Processing Record 23 of Set 4 | luderitz
# Processing Record 24 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | paamiut
# Processing Record 27 of Set 4 | wattegama
# Processing Record 28 of Set 4 | kununurra
# Processing Record 29 of Set 4 | grants
# Processing Record 30 of Set 4 | luang prabang
# Processing Record 31 of Set 4 | kerteh
# City not found. Skipping...
# Processing Record 32 of Set 4 | xiutetelco
# City not found. Skipping...
# Processing Record 33 of Set 4 | salisbury
# Processing Record 34 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 4 | ilinskaya
# Processing Record 36 of Set 4 | merauke
# Processing Record 37 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 4 | rensvik
# Processing Record 39 of Set 4 | samarai
# Processing Record 40 of Set 4 | barguzin
# Processing Record 41 of Set 4 | karabulak
# Processing Record 42 of Set 4 | itarema
# Processing Record 43 of Set 4 | christiana
# Processing Record 44 of Set 4 | carnarvon
# Processing Record 45 of Set 4 | pisco
# Processing Record 46 of Set 4 | fethiye
# Processing Record 47 of Set 4 | alamos
# Processing Record 48 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 4 | jardim
# Processing Record 50 of Set 4 | torbay
# Processing Record 1 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 5 | adrar
# Processing Record 3 of Set 5 | carutapera
# Processing Record 4 of Set 5 | calama
# Processing Record 5 of Set 5 | ribeira grande
# Processing Record 6 of Set 5 | kawalu
# Processing Record 7 of Set 5 | trat
# Processing Record 8 of Set 5 | san patricio
# Processing Record 9 of Set 5 | moscow
# Processing Record 10 of Set 5 | fairbanks
# Processing Record 11 of Set 5 | san blas
# Processing Record 12 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 5 | anloga
# Processing Record 14 of Set 5 | vilhena
# Processing Record 15 of Set 5 | mount gambier
# Processing Record 16 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 5 | taltal
# Processing Record 18 of Set 5 | sungai siput utara
# City not found. Skipping...
# Processing Record 19 of Set 5 | show low
# Processing Record 20 of Set 5 | souillac
# Processing Record 21 of Set 5 | mahebourg
# Processing Record 22 of Set 5 | lebu
# Processing Record 23 of Set 5 | cayenne
# Processing Record 24 of Set 5 | rameswaram
# Processing Record 25 of Set 5 | ebano
# City not found. Skipping...
# Processing Record 26 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 27 of Set 5 | staryy nadym
# Processing Record 28 of Set 5 | derzhavinsk
# Processing Record 29 of Set 5 | zhezkazgan
# Processing Record 30 of Set 5 | bhind
# Processing Record 31 of Set 5 | panaba
# Processing Record 32 of Set 5 | sabya
# Processing Record 33 of Set 5 | port blair
# Processing Record 34 of Set 5 | saint george
# Processing Record 35 of Set 5 | green river
# Processing Record 36 of Set 5 | krasnoselkup
# Processing Record 37 of Set 5 | kapustin yar
# Processing Record 38 of Set 5 | raudeberg
# Processing Record 39 of Set 5 | isangel
# Processing Record 40 of Set 5 | kiunga
# Processing Record 41 of Set 5 | pevek
# Processing Record 42 of Set 5 | mogadishu
# Processing Record 43 of Set 5 | alice springs
# Processing Record 44 of Set 5 | marsa matruh
# Processing Record 45 of Set 5 | cabo san lucas
# Processing Record 46 of Set 5 | khandyga
# Processing Record 47 of Set 5 | kloulklubed
# Processing Record 48 of Set 5 | nikolskoye
# Processing Record 49 of Set 5 | geraldton
# Processing Record 50 of Set 5 | bengkulu
# Processing Record 1 of Set 6 | fianarantsoa
# Processing Record 2 of Set 6 | nago
# Processing Record 3 of Set 6 | hun
# Processing Record 4 of Set 6 | sobolevo
# Processing Record 5 of Set 6 | muswellbrook
# Processing Record 6 of Set 6 | sal rei
# Processing Record 7 of Set 6 | oistins
# Processing Record 8 of Set 6 | mar del plata
# Processing Record 9 of Set 6 | clyde river
# Processing Record 10 of Set 6 | castro
# Processing Record 11 of Set 6 | grindavik
# Processing Record 12 of Set 6 | vangaindrano
# Processing Record 13 of Set 6 | dianopolis
# City not found. Skipping...
# Processing Record 14 of Set 6 | snasa
# Processing Record 15 of Set 6 | swan hill
# Processing Record 16 of Set 6 | sylvan lake
# Processing Record 17 of Set 6 | synya
# Processing Record 18 of Set 6 | korla
# Processing Record 19 of Set 6 | sur
# Processing Record 20 of Set 6 | salalah
# Processing Record 21 of Set 6 | pangnirtung
# Processing Record 22 of Set 6 | jertih
# Processing Record 23 of Set 6 | bonavista
# Processing Record 24 of Set 6 | laguna
# Processing Record 25 of Set 6 | tooele
# Processing Record 26 of Set 6 | uitenhage
# Processing Record 27 of Set 6 | poya
# Processing Record 28 of Set 6 | prince rupert
# Processing Record 29 of Set 6 | maxixe
# Processing Record 30 of Set 6 | nalut
# Processing Record 31 of Set 6 | luena
# Processing Record 32 of Set 6 | mehamn
# Processing Record 33 of Set 6 | gora
# Processing Record 34 of Set 6 | ola
# Processing Record 35 of Set 6 | victoria
# Processing Record 36 of Set 6 | muyezerskiy
# Processing Record 37 of Set 6 | dehui
# Processing Record 38 of Set 6 | bahia honda
# Processing Record 39 of Set 6 | nalobikha
# Processing Record 40 of Set 6 | coffs harbour
# Processing Record 41 of Set 6 | college
# Processing Record 42 of Set 6 | isiro
# Processing Record 43 of Set 6 | monastyrshchina
# Processing Record 44 of Set 6 | puerto leguizamo
# Processing Record 45 of Set 6 | sines
# Processing Record 46 of Set 6 | margate
# Processing Record 47 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 6 | wana
# Processing Record 49 of Set 6 | puerto ayora
# Processing Record 50 of Set 6 | tall kayf
# Processing Record 1 of Set 7 | akyab
# Processing Record 2 of Set 7 | novoilinsk
# Processing Record 3 of Set 7 | sitka
# Processing Record 4 of Set 7 | vostok
# Processing Record 5 of Set 7 | namatanai
# Processing Record 6 of Set 7 | saint-pierre
# Processing Record 7 of Set 7 | aykhal
# Processing Record 8 of Set 7 | tautira
# Processing Record 9 of Set 7 | asau
# Processing Record 10 of Set 7 | sao joao da barra
# Processing Record 11 of Set 7 | codrington
# Processing Record 12 of Set 7 | kaitangata
# Processing Record 13 of Set 7 | bolshevik
# Processing Record 14 of Set 7 | nara
# Processing Record 15 of Set 7 | fortuna
# Processing Record 16 of Set 7 | port lincoln
# Processing Record 17 of Set 7 | zabid
# Processing Record 18 of Set 7 | srandakan
# Processing Record 19 of Set 7 | erzin
# Processing Record 20 of Set 7 | san ramon
# Processing Record 21 of Set 7 | tabialan
# City not found. Skipping...
# Processing Record 22 of Set 7 | buarcos
# Processing Record 23 of Set 7 | duekoue
# Processing Record 24 of Set 7 | safaga
# Processing Record 25 of Set 7 | iskateley
# Processing Record 26 of Set 7 | shelby
# Processing Record 27 of Set 7 | tabou
# Processing Record 28 of Set 7 | kirensk
# Processing Record 29 of Set 7 | dolores
# Processing Record 30 of Set 7 | lydenburg
# Processing Record 31 of Set 7 | coihaique
# Processing Record 32 of Set 7 | sumenep
# Processing Record 33 of Set 7 | ketchikan
# Processing Record 34 of Set 7 | tateyama
# Processing Record 35 of Set 7 | ugoofaaru
# Processing Record 36 of Set 7 | lima
# Processing Record 37 of Set 7 | slidell
# Processing Record 38 of Set 7 | beloha
# Processing Record 39 of Set 7 | vallenar
# Processing Record 40 of Set 7 | aginskoye
# Processing Record 41 of Set 7 | san felipe
# Processing Record 42 of Set 7 | vanimo
# Processing Record 43 of Set 7 | southbridge
# Processing Record 44 of Set 7 | fort nelson
# Processing Record 45 of Set 7 | chuy
# Processing Record 46 of Set 7 | trinidad
# Processing Record 47 of Set 7 | charagua
# Processing Record 48 of Set 7 | fengzhen
# Processing Record 49 of Set 7 | polson
# Processing Record 50 of Set 7 | soria
# Processing Record 1 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 8 | chumikan
# Processing Record 3 of Set 8 | srednekolymsk
# Processing Record 4 of Set 8 | zeerust
# Processing Record 5 of Set 8 | katsuura
# Processing Record 6 of Set 8 | champerico
# Processing Record 7 of Set 8 | hays
# Processing Record 8 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 8 | mapiri
# Processing Record 10 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 11 of Set 8 | manokwari
# Processing Record 12 of Set 8 | mnogovershinnyy
# Processing Record 13 of Set 8 | makakilo city
# Processing Record 14 of Set 8 | padre bernardo
# Processing Record 15 of Set 8 | olinda
# Processing Record 16 of Set 8 | bardiyah
# Processing Record 17 of Set 8 | copiapo
# Processing Record 18 of Set 8 | portlethen
# Processing Record 19 of Set 8 | saint-augustin
# Processing Record 20 of Set 8 | chabahar
# Processing Record 21 of Set 8 | beringovskiy
# Processing Record 22 of Set 8 | manggar
# Processing Record 23 of Set 8 | manavalakurichi
# Processing Record 24 of Set 8 | newport
# Processing Record 25 of Set 8 | atambua
# Processing Record 26 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 27 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 8 | coquimatlan
# Processing Record 29 of Set 8 | atar
# Processing Record 30 of Set 8 | kruisfontein
# Processing Record 31 of Set 8 | vastseliina
# Processing Record 32 of Set 8 | minab
# Processing Record 33 of Set 8 | awjilah
# Processing Record 34 of Set 8 | carbonia
# Processing Record 35 of Set 8 | vila velha
# Processing Record 36 of Set 8 | talnakh
# Processing Record 37 of Set 8 | auki
# Processing Record 38 of Set 8 | nioro
# Processing Record 39 of Set 8 | benguela
# Processing Record 40 of Set 8 | rio gallegos
# Processing Record 41 of Set 8 | grand gaube
# Processing Record 42 of Set 8 | gambela
# Processing Record 43 of Set 8 | yulin
# Processing Record 44 of Set 8 | salinopolis
# Processing Record 45 of Set 8 | valparaiso
# Processing Record 46 of Set 8 | impfondo
# Processing Record 47 of Set 8 | mayumba
# Processing Record 48 of Set 8 | yumen
# Processing Record 49 of Set 8 | khani
# Processing Record 50 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 9 | bemidji
# Processing Record 2 of Set 9 | catuday
# Processing Record 3 of Set 9 | shelburne
# Processing Record 4 of Set 9 | honningsvag
# Processing Record 5 of Set 9 | tabora
# Processing Record 6 of Set 9 | uvalde
# Processing Record 7 of Set 9 | agua prieta
# Processing Record 8 of Set 9 | hirara
# Processing Record 9 of Set 9 | vershino-darasunskiy
# Processing Record 10 of Set 9 | kirakira
# Processing Record 11 of Set 9 | ilulissat
# Processing Record 12 of Set 9 | nampula
# Processing Record 13 of Set 9 | moron
# Processing Record 14 of Set 9 | lasa
# Processing Record 15 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 16 of Set 9 | zapolyarnyy
# Processing Record 17 of Set 9 | marsh harbour
# Processing Record 18 of Set 9 | broome
# Processing Record 19 of Set 9 | haapsalu
# Processing Record 20 of Set 9 | busko-zdroj
# Processing Record 21 of Set 9 | dunedin
# Processing Record 22 of Set 9 | nouadhibou
# Processing Record 23 of Set 9 | road town
# Processing Record 24 of Set 9 | lalmohan
# Processing Record 25 of Set 9 | yangliuqing
# Processing Record 26 of Set 9 | salta
# Processing Record 27 of Set 9 | izazi
# Processing Record 28 of Set 9 | ballina
# Processing Record 29 of Set 9 | gobabis
# Processing Record 30 of Set 9 | akdepe
# Processing Record 31 of Set 9 | cap malheureux
# Processing Record 32 of Set 9 | ucluelet
# Processing Record 33 of Set 9 | kindia
# Processing Record 34 of Set 9 | alofi
# Processing Record 35 of Set 9 | barmer
# Processing Record 36 of Set 9 | visnes
# Processing Record 37 of Set 9 | corowa
# Processing Record 38 of Set 9 | ayorou
# Processing Record 39 of Set 9 | horta
# Processing Record 40 of Set 9 | babai
# Processing Record 41 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 42 of Set 9 | cockburn town
# Processing Record 43 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 9 | ulladulla
# Processing Record 45 of Set 9 | bubaque
# Processing Record 46 of Set 9 | mackenzie
# Processing Record 47 of Set 9 | huangzhou
# Processing Record 48 of Set 9 | bilibino
# Processing Record 49 of Set 9 | umm jarr
# City not found. Skipping...
# Processing Record 50 of Set 9 | ksenyevka
# City not found. Skipping...
# Processing Record 1 of Set 10 | touros
# Processing Record 2 of Set 10 | comarapa
# Processing Record 3 of Set 10 | gazanjyk
# Processing Record 4 of Set 10 | marietta
# Processing Record 5 of Set 10 | fort saint james
# Processing Record 6 of Set 10 | belyy yar
# Processing Record 7 of Set 10 | kieta
# Processing Record 8 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 10 | slave lake
# Processing Record 10 of Set 10 | leh
# Processing Record 11 of Set 10 | sola
# Processing Record 12 of Set 10 | aleksandrov gay
# Processing Record 13 of Set 10 | kokopo
# Processing Record 14 of Set 10 | buraydah
# Processing Record 15 of Set 10 | palu
# Processing Record 16 of Set 10 | maraba
# Processing Record 17 of Set 10 | anaconda
# Processing Record 18 of Set 10 | coahuayana
# Processing Record 19 of Set 10 | cururupu
# Processing Record 20 of Set 10 | camacupa
# Processing Record 21 of Set 10 | praia grande
# Processing Record 22 of Set 10 | ukiah
# Processing Record 23 of Set 10 | port macquarie
# Processing Record 24 of Set 10 | hambantota
# Processing Record 25 of Set 10 | resistencia
# Processing Record 26 of Set 10 | matara
# Processing Record 27 of Set 10 | maningrida
# Processing Record 28 of Set 10 | najran
# Processing Record 29 of Set 10 | kolpashevo
# Processing Record 30 of Set 10 | tubuala
# Processing Record 31 of Set 10 | marawi
# Processing Record 32 of Set 10 | charters towers
# Processing Record 33 of Set 10 | pangoa
# Processing Record 34 of Set 10 | kresttsy
# Processing Record 35 of Set 10 | san quintin
# Processing Record 36 of Set 10 | kavaratti
# Processing Record 37 of Set 10 | camana
# Processing Record 38 of Set 10 | shenxian
# Processing Record 39 of Set 10 | juli
# Processing Record 40 of Set 10 | guarapari
# Processing Record 41 of Set 10 | razole
# Processing Record 42 of Set 10 | sharjah
# Processing Record 43 of Set 10 | birao
# Processing Record 44 of Set 10 | ambilobe
# Processing Record 45 of Set 10 | shimoda
# Processing Record 46 of Set 10 | olafsvik
# Processing Record 47 of Set 10 | potsdam
# Processing Record 48 of Set 10 | yichun
# Processing Record 49 of Set 10 | rawson
# Processing Record 50 of Set 10 | sibolga
# Processing Record 1 of Set 11 | dahuk
# Processing Record 2 of Set 11 | teknaf
# Processing Record 3 of Set 11 | peterhead
# Processing Record 4 of Set 11 | moen
# Processing Record 5 of Set 11 | kalmunai
# Processing Record 6 of Set 11 | kota kinabalu
# Processing Record 7 of Set 11 | caravelas
# Processing Record 8 of Set 11 | bandarbeyla
# Processing Record 9 of Set 11 | manzhouli
# Processing Record 10 of Set 11 | beneditinos
# Processing Record 11 of Set 11 | bathsheba
# Processing Record 12 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 13 of Set 11 | luanda
# Processing Record 14 of Set 11 | elbrus
# Processing Record 15 of Set 11 | magadan
# Processing Record 16 of Set 11 | sistranda
# Processing Record 17 of Set 11 | saldanha
# Processing Record 18 of Set 11 | shushenskoye
# Processing Record 19 of Set 11 | sawtell
# Processing Record 20 of Set 11 | sisimiut
# Processing Record 21 of Set 11 | bataipora
# Processing Record 22 of Set 11 | rincon
# Processing Record 23 of Set 11 | port-gentil
# Processing Record 24 of Set 11 | sorong
# Processing Record 25 of Set 11 | emborion
# Processing Record 26 of Set 11 | sao felix do xingu
# Processing Record 27 of Set 11 | posse
# Processing Record 28 of Set 11 | tabuk
# Processing Record 29 of Set 11 | takoradi
# Processing Record 30 of Set 11 | fitjar
# Processing Record 31 of Set 11 | rocha
# Processing Record 32 of Set 11 | wad madani
# Processing Record 33 of Set 11 | byron bay
# Processing Record 34 of Set 11 | mazurivka
# Processing Record 35 of Set 11 | longyearbyen
# Processing Record 36 of Set 11 | palmeirais
# Processing Record 37 of Set 11 | adelaide
# Processing Record 38 of Set 11 | siniscola
# Processing Record 39 of Set 11 | taoudenni
# Processing Record 40 of Set 11 | krasyliv
# Processing Record 41 of Set 11 | batagay-alyta
# Processing Record 42 of Set 11 | jaque
# Processing Record 43 of Set 11 | malangwa
# Processing Record 44 of Set 11 | puerto escondido
# Processing Record 45 of Set 11 | ust-kut
# Processing Record 46 of Set 11 | dukat
# Processing Record 47 of Set 11 | muzquiz
# City not found. Skipping...
# Processing Record 48 of Set 11 | warri
# Processing Record 49 of Set 11 | leningradskiy
# Processing Record 50 of Set 11 | tsuruoka
# Processing Record 1 of Set 12 | george
# Processing Record 2 of Set 12 | iqaluit
# Processing Record 3 of Set 12 | toppenish
# Processing Record 4 of Set 12 | vanavara
# Processing Record 5 of Set 12 | larsnes
# Processing Record 6 of Set 12 | kpalime
# Processing Record 7 of Set 12 | goderich
# Processing Record 8 of Set 12 | saint-francois
# Processing Record 9 of Set 12 | dwarka
# Processing Record 10 of Set 12 | faanui
# Processing Record 11 of Set 12 | yanam
# Processing Record 12 of Set 12 | imeni poliny osipenko
# Processing Record 13 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 12 | zyryanovsk
# Processing Record 15 of Set 12 | moose factory
# Processing Record 16 of Set 12 | acapulco
# Processing Record 17 of Set 12 | vyartsilya
# Processing Record 18 of Set 12 | cabedelo
# Processing Record 19 of Set 12 | rossland
# Processing Record 20 of Set 12 | peace river
# Processing Record 21 of Set 12 | westport
# Processing Record 22 of Set 12 | fonte boa
# Processing Record 23 of Set 12 | yenagoa
# Processing Record 24 of Set 12 | ekibastuz
# Processing Record 25 of Set 12 | puerto barrios
# Processing Record 26 of Set 12 | almenara
# Processing Record 27 of Set 12 | eregli
# Processing Record 28 of Set 12 | udachnyy
# Processing Record 29 of Set 12 | launceston
# Processing Record 30 of Set 12 | hammerfest
# Processing Record 31 of Set 12 | la ronge
# Processing Record 32 of Set 12 | santa rosa
# Processing Record 33 of Set 12 | palafrugell
# Processing Record 34 of Set 12 | payo
# Processing Record 35 of Set 12 | gat
# Processing Record 36 of Set 12 | havre-saint-pierre
# Processing Record 37 of Set 12 | eydhafushi
# Processing Record 38 of Set 12 | buta
# Processing Record 39 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 40 of Set 12 | mason city
# Processing Record 41 of Set 12 | jalapa
# Processing Record 42 of Set 12 | sechura
# Processing Record 43 of Set 12 | ca mau
# Processing Record 44 of Set 12 | imatra
# Processing Record 45 of Set 12 | severobaykalsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bang Len      TH  14.02  100.17     86.00        79          40
# 1           Bluff      NZ -46.60  168.33     48.52        78          85
# 2      Nanortalik      GL  60.14  -45.24     43.75        79          92
# 3         Ushuaia      AR -54.80  -68.30     37.40        74          75
# 4       Jamestown      US  42.10  -79.24     73.40        60          75
# 5       Ladybrand      ZA -29.19   27.46     35.46        85           0
# 6        Cherskiy      RU  68.75  161.30     40.51        70          82
# 7  Saint-Philippe      RE -21.36   55.77     69.80        77          35
# 8          Amazar      RU  53.86  120.88     55.31        88           1
# 9         Mareeba      AU -17.00  145.43     69.80        83          90
#
#    Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0        8.05    scattered clouds            0.0            0.0
# 1        8.59     overcast clouds            0.0            0.0
# 2       10.98     overcast clouds            0.0            0.0
# 3       14.99       broken clouds            0.0            0.0
# 4       12.75       broken clouds            0.0            0.0
# 5        4.90           clear sky            0.0            0.0
# 6        6.08       broken clouds            0.0            0.0
# 7        3.36    scattered clouds            0.0            0.0
# 8        2.86           clear sky            0.0            0.0
# 9       10.29     overcast clouds            0.0            0.0

# %%
# Create the output file (CSV).
output_data_file = "data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
